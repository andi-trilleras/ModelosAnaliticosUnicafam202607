# %% [markdown]
# <a href="https://colab.research.google.com/github/andi-trilleras/ModelosAnaliticosUnicafam202607/blob/main/TallerFinalPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Taller Final Python**
#
# Modelos Analìticos
#
# Docente: Nicolas Mojica
#
# Estudiante: Andrea Trilleras

# %% [markdown]
# ##Variables

# %%
#Crea 5 variables que describan a una persona: nombre, apellido, edad, altura (en metros) y si está activa o no. Luego imprime cada una con print()
nombre="Andrea"
apellido="Trilleras"
edad=30
altura=1.53
activa=True
print (f"Nombre:",nombre)
print (f"Apellido:",apellido)
print ("Edad:",edad)
print(f"Altura:",altura)
print(f"¿Está activo?:",activa)
# Out:
# Nombre: Andrea
# Apellido: Trilleras
# Edad: 30
# Altura: 1.53
# ¿Está activo?: True

# %%
#Sin correr el código, escribe exactamente qué imprimirá cada print():
x = 10
y = x
x = 20
print(x)
print(y)
# Out:
# 20
# 10

# %%
#Tienes a = "hola" y b = "mundo". Sin escribir el texto directamente, intercambia los valores para que a quede con "mundo" y b con "hola". Imprime ambas al final.
a = "hola"
b = a
a = "mundo"
print(a)
print(b)
# Out:
# mundo
# hola

# %%
#Tres de estas declaraciones tienen un error. Identifica cuáles y explica por qué:
1nombre = "Carlos"
mi_apellido = "Ruiz"
mi ciudad = "Bogotá"
_privado = 42
class = "matemáticas"
#Linea1: porque no puede iniciar con número
#Linea 3: porque no pueden ser palabras separadas
#Linea 5: porque class es una palabra que ya hace parte de Python y no se puede usar como variable

# %%
#Conversion de tipos
#El usuario ingresó su edad como texto: edad_texto = "23". Escribe el código para: (1) convertirla a entero, (2) sumarle 10, (3) imprimirla.
#Luego convierte el número 3.9 a entero e imprime el resultado — ¿qué pasa?
edad_texto = "23"
edad_entero=int(edad_texto)
edad_entero+=10
print (edad_entero)

#Para redondear 3.9 sale error utilizando int. El ejercicio sugirió:
print(round(3.9))
# Out:
# 33
# 4

# %%
"""Declara variables para un estudiante (nombre, semestre, promedio, beca). Luego imprime una sola línea con el formato:
Ana López | Semestre 3 | Promedio: 4.2 | Beca: True
Usa f-strings (f"...") para armar el texto
"""
# Out:
# 'Declara variables para un estudiante (nombre, semestre, promedio, beca). Luego imprime una sola línea con el formato:\nAna López | Semestre 3 | Promedio: 4.2 | Beca: True\nUsa f-strings (f"...") para armar el texto\n'

# %%
nombre="Ana López"
semestre= "Semestre 3"
promedio= 4.2
beca= True
print(f"{nombre}|{semestre}|Promedio: {promedio}|Beca: {beca}")
# Out:
# Ana López|Semestre 3|Promedio: 4.2|Beca: True

# %% [markdown]
# ##Operaciones

# %%
#Sin correr el código, escribe el resultado de cada operación:
a = 17
b = 5
print(a + b) #22
print(a - b) #12
print(a * b) #85
print(a / b) #3.4
print(a // b) #3
print(a % b) #2
print(a ** 2) #289
# Out:
# 22
# 12
# 85
# 3.4
# 3
# 2
# 289

# %%
#La cuenta de un restaurante es $85,000. Calcula e imprime: la propina del 15%, el total a pagar (cuenta + propina), y cuánto paga cada persona si son 4.
cuenta=85000
propina=cuenta*0.15
total_pagar=cuenta+propina
print(f"La cuenta total es: ${total_pagar} ")
print(f"La cuenta total por cada persona es:${total_pagar/4} ")
# Out:
# La cuenta total es: $97750.0
# La cuenta total por cada persona es:$24437.5

# %%
#¿True o False devuelve cada expresión?

x = 8
print(x == 8)
print(x != 8)
print(x > 5)
print(x < 5)
print(x >= 8)
print(3 < x < 10)
# Out:
# True
# False
# True
# False
# True
# True

# %%
#Escribe código que convierta 37.5 grados Celsius a Fahrenheit. La fórmula es F = C × 9/5 + 32. Imprime el resultado con 1 decimal.
celsius=37.5
fah= celsius*(9/5)+32
print(f"{celsius}C = {fah:.1f}F")
# Out:
# 37.5C = 99.5F

# %%
#Usando el operador %, escribe una expresión que dé True si el número n = 42 es par, y False si es impar. Imprime el resultado y una explicación.
n=42
es_par=(n%2==0)
print(f"{n} Es par: {es_par}")
# Out:
# 42 Es par: True

# %%
#Un parque de diversiones cobra $15,000 a adultos (18-60 años) y $8,000 a niños o adultos mayores. El precio se duplica los fines de semana. Dado edad = 25 y fin_de_semana = True, calcula el precio a pagar usando operadores lógicos.
edad=25
finde=True
adulto=(edad>=18 and edad<60)
nino= (edad<18)
if adulto and finde==True:
  precio=15000
  precio_total=precio*2
  print(f"El precio total es: {precio_total}")
elif adulto and finde==False:
  print(f"El precio total es: {precio}")
elif nino and finde==False:
  precio=8000
  print(f"El precio total es: {precio}")
else:
  precio_total= precio*2
  print(f"El precio total es: {precio}")
# Out:
# El precio total es: 30000
