# %% [markdown]
# <a href="https://colab.research.google.com/github/andi-trilleras/ModelosAnaliticosUnicafam202607/blob/main/Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Funciones

# %%
#Crea una función que te salude de acuerdo a tu nombre
def saludar(nombre):
  print(f"Hola, esta es mi primer funcion. Mi nombre es {nombre}")
saludar("Andrea")
# Out:
# Hola, esta es mi primer funcion. Mi nombre es Andrea

# %%
#Crea una funcion de suma
def suma (a,b):
  return a+b
resultado=suma(2,2)
print(resultado)
# Out:
# 4

# %%
#Presentacion con edad
def presentacion (nombre,edad=30):
 print(f"Hola mi nombre es {nombre} y tengo {edad} años")
presentacion("Andrea")
# Out:
# Hola mi nombre es Andrea y tengo 30 años

# %%
#Genera calculadora de operaciones
def operaciones (a,b):
 suma= a+b
 resta= a-b
 mult= a*b
 division=a/b
 return suma,resta,mult,division
result_suma, result_resta, result_mult, result_division= operaciones(8,5)
print(f"Suma:{result_suma}, Resta: {result_resta}, Mult:{result_mult}, Division: {result_division}")
# Out:
# Suma:13, Resta: 3, Mult:40, Division: 1.6

# %% [markdown]
# ##Ejercicio 1

# %%
##Escriba una funcion que reciba la edad de una persona y determine si es mayor o menor de edad
def mayoria (edad):
  if (edad>=18):
    print(f"Tienes {edad} años, eres mayor de edad")

  else:
     print(f"Tienes {edad} años, eres menor de edad")

return print(mayoria)
# Out:
#   File "/tmp/ipykernel_1510/3049413408.py", line 9
#     return print(mayoria)
#     ^
# SyntaxError: 'return' outside function

# %%
def imc (peso, altura):
  indice=peso/(altura**2)
  if indice>=30:
    print("Obesidad")
  elif indice>=25:
    print("Sobrepeso")
  elif indice>=18.5:
    print("Normal")
  else:
    print("Bajo peso")

peso= (float(input("Ingrese su peso:")))
altura= (float(input("Ingrese su altura:")))
imc (peso, altura)
# Out:
# Ingrese su peso:80
# Ingrese su altura:153
# Bajo peso
