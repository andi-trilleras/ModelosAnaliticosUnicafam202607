# %% [markdown]
# <a href="https://colab.research.google.com/github/andi-trilleras/ModelosAnaliticosUnicafam202607/blob/main/EjercicioClase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ESTRUCTURAS DE DATOS - Creación y Modificación de Listas**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: ANDREA TRILLERAS

# %%
#Crea una lista llamada números que contenga los números del 1 al 5
numeros=[1,2,3,4,5]
print(numeros)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Añade el número 6 al final de la lista numeros.
numeros.append(6)
print (numeros)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Cambia el segundo elemento de la lista numeros a 10
numeros.insert(1,10)
print(numeros)
# Out:
# [1, 10, 2, 3, 4, 5, 6]

# %%
#Elimina el cuarto elemento de la lista numeros
numeros.remove(3)
print(numeros)
# Out:
# [1, 10, 2, 4, 5, 6]
